# %%
import pickle
import matplotlib.pyplot as plt

# %%
def plot_lc(loss_dict_name, title):
    with open(f'{loss_dict_name}.pickle', 'rb') as handle:
        loss_dict = pickle.load(handle) 
        plt.title(title)
        plt.plot(loss_dict['train'], label = 'train', color = 'black')
        plt.plot(loss_dict['val'], label = 'validation', color = 'royalblue')
        plt.xlabel('Number of epochs')
        plt.ylabel('MSE')
        plt.legend()   
        
        try:
            print(loss_dict['maximum_distance'])
        except:
            print('no att')

# %%
plot_lc('fcn', 'Fully Connected')
# Out:
# no att

# %%
plot_lc('gcn', 'Graph ConvNet')
# Out:
# 1

# %%
plot_lc('gcn', 'Graph ConvNet')
# Out:
# 0.5

# %%
plot_lc('gat', 'Graph ConvNet + Multihead Attention')
# Out:
# 2
